# %% [markdown]
# The scope of this notebook is to practice in cleaning a messy dataset, specifically the dataset about information on TV commercials from 5 indian TV channels.
#
# Let's start by loading the tidyverse and the data.table packages.

# %%
library(tidyverse)
library(data.table)

# %% [markdown]
# Now, I create the string name that contains the files to be read and load the data in it. For the moment I focus only on the BBC file

# %%
file_folder <- 'TV_News_Channel_Commercial_Detection_Dataset/'
BBC_file <- paste(file_folder, 'BBC.txt', sep = '')

BBC_data <- read.table(BBC_file, col.names = as.character(c(0:4125)), fill = TRUE)

# %%
summary(BBC_data, 20)
# Out:
#        X0                 X1                 X2                 X3
#  Min.   :-1.00000   1:25   : 2162   2:0.000000: 4014   3:0.000000: 4014
#  1st Qu.:-1.00000   1:29   :  356   2:0.065844:    2   3:0.189225:    2
#  Median :-1.00000   1:26   :  327   2:0.086061:    2   3:0.190645:    2
#  Mean   :-0.05011   1:28   :  295   2:0.263408:    2   3:0.215913:    2
#  3rd Qu.: 1.00000   1:32   :  278   2:0.362106:    2   3:0.307790:    2
#  Max.   : 1.00000   1:27   :  271   2:0.754132:    2   3:0.357110:    2
#                     1:36   :  246   2:0.774367:    2   3:0.392698:    2
#                     1:33   :  244   2:1.215915:    2   3:0.401722:    2
#                     1:34   :  242   2:1.385334:    2   3:0.414633:    2
#                     1:30   :  240   2:1.781134:    2   3:0.487758:    2
#                     1:45   :  228   2:1.861384:    2   3:0.669710:    2
#                     1:41   :  226   2:2.551774:    2   3:0.711167:    2
# ...
